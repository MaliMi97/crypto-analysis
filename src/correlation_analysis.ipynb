# %% [markdown]
# Computes whether the prices and returns of assets correlates with each other. Also looks into the risks and return of assets.

# %%
from datetime import datetime
import pandas as pd
from api.CoinGeckoAPI import CoinGeckoAPI
from functions.functions import *
from visualization.line_graph import *
from visualization.comparisons import *
from functions.impermanent_loss import *

# %%
coin_list = ['bitcoin', 'ethereum', 'solana', 'polkadot', 'the-sandbox', 'decentraland']
c = CoinGeckoAPI()
end = datetime.now()
start = datetime(end.year-1, end.month, end.day)

# %%
for coin in coin_list:
    globals()[coin+"_d"] = c.get_price_cap_volume(start, end, coin=coin, period='day')
    globals()[coin+"_w"] = c.get_price_cap_volume(start, end, coin=coin, period='week')
daily, weekly = pd.DataFrame(), pd.DataFrame()
for coin in coin_list:
    daily[coin+"_d"] = globals()[coin+"_d"]['price']
    weekly[coin+"_w"] = globals()[coin+"_w"]['price']

# %%
correlation_analysis(daily)
# Out:
# Prices:
#           bitcoin_d   ethereum_d    solana_d  polkadot_d  the-sandbox_d  \
# count    365.000000   365.000000  365.000000  365.000000     365.000000
# mean   46832.362939  3083.800593  101.837534   28.254353       2.011382
# std     9247.350045   792.303661   68.417759   10.019922       1.983496
# min    29971.903784  1581.631056   12.964523   11.074336       0.175481
# 25%    39090.202154  2465.219230   36.248760   19.140042       0.573489
# 50%    46311.001899  3012.308559   90.107985   27.014187       0.767727
# 75%    54991.814843  3752.618727  159.863492   35.549524       3.286574
# max    67617.015545  4815.004634  259.239558   54.142860       7.513639
#
#        decentraland_d
# count      365.000000
# mean         1.740274
# std          1.180843
# min          0.437131
# 25%          0.771694
# 50%          1.079371
# 75%          2.832719
# max          5.198887
# Returns:
#         bitcoin_d  ethereum_d    solana_d  polkadot_d  the-sandbox_d  \
# count  364.000000  364.000000  364.000000  364.000000     364.000000
# mean    -0.000176    0.002582    0.007768    0.000481       0.009525
# std      0.038437    0.050697    0.074306    0.067800       0.102368
# min     -0.134683   -0.263025   -0.363744   -0.373599      -0.373380
# 25%     -0.021222   -0.025982   -0.033886   -0.036950      -0.041436
# 50%     -0.000199    0.004983    0.001508    0.001518      -0.005731
# 75%      0.021747    0.032814    0.042160    0.037497       0.046413
# max      0.143421    0.245336    0.296631    0.277625       0.652815
#
#        decentraland_d
# count      364.000000
# mean         0.007037
# std          0.111515
# min         -0.297897
# 25%         -0.041528
# 50%         -0.003556
# 75%          0.039279
# max          1.516583

# %%
correlation_analysis(weekly)
# Out:
# Prices:
#           bitcoin_w   ethereum_w    solana_w  polkadot_w  the-sandbox_w  \
# count     51.000000    51.000000   51.000000   51.000000      51.000000
# mean   46433.793663  3107.073581  104.759306   28.049443       2.065056
# std     9372.531942   782.785529   69.209122   10.265402       1.998974
# min    31588.671351  1817.047666   22.598963   12.274410       0.184818
# 25%    38996.947851  2393.684800   37.954193   19.080560       0.624725
# 50%    46780.902305  3018.673398   92.404085   27.744647       0.776595
# 75%    52598.445492  3817.407168  169.659334   35.662518       3.378413
# max    64660.335353  4666.498498  259.239558   52.077704       6.768167
#
#        decentraland_w
# count       51.000000
# mean         1.802805
# std          1.213554
# min          0.466886
# 25%          0.782679
# 50%          1.106827
# 75%          2.912671
# max          4.668149
# Returns:
#        bitcoin_w  ethereum_w   solana_w  polkadot_w  the-sandbox_w  \
# count  50.000000   50.000000  50.000000   50.000000      50.000000
# mean   -0.001722    0.017015   0.048725   -0.000497       0.071169
# std     0.092428    0.136961   0.215722    0.163740       0.321427
# min    -0.204026   -0.369830  -0.360100   -0.490937      -0.382494
# 25%    -0.061133   -0.055123  -0.078696   -0.093605      -0.117262
# 50%     0.004608    0.006279  -0.009944    0.000930      -0.004869
# 75%     0.064616    0.083604   0.183874    0.123944       0.157075
# max     0.220397    0.330829   0.684367    0.266212       1.305715
#
#        decentraland_w
# count       50.000000
# mean         0.073926
# std          0.517159
# min         -0.367481
# 25%         -0.118227
# 50%         -0.001932
# 75%          0.107965
# max          3.442266
